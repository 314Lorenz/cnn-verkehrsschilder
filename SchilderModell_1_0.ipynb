# %% [markdown]
# # German traffic sign classification
#
# ### Aufgaben:
# 1. Schauen Sie sich das Notebook „data exploration.ipynb“ an, um eine Idee von dem „German Traffic Sign Recognition“-Datensatz zu bekommen.
# 2.	Trainieren Sie verschiedene Modelle mit unterschiedlichen Architekturen. Erstellen Sie mindestens drei unterschiedliche Modelle. Das Notebook „student_task.ipynb“ gibt eine grobe Struktur vor, wie Sie Ihre Modelle trainieren können.
# 3.	Vergleichen Sie die Modelle mithilfe einer Konfusionsmatrix und wählen Sie das beste Modell aus. Jedes Modell sollte mindestens eine Accuracy von 90 % auf dem Validierungsdatensatz erreichen. Begründen Sie Ihre Auswahl anhand der Konfusionsmatrix. Gehen Sie in Ihrer Analyse auf folgende Fragen ein:
#     - „Welche Klassen werden besonders häufig verwechselt?“
#     - „Zeigt ein Modell auffällige Schwächen bei bestimmten Verkehrszeichen?“
#     - „Gibt es Klassen, die von allen Modellen zuverlässig erkannt werden?“
#     - „Ist das Modell mit der höchsten Accuracy auch in der Konfusionsmatrix am überzeugendsten?“
# 4.	Testen sie das finale Modell und erstellen sie eine Konfusionsmatrix. Welche Unterschiede fallen Ihnen im Vergleich zu den Ergebnissen auf den Validierungsdaten auf?
# 5.	Erstellen Sie eine kurze Präsentation, die Ihre Ergebnisse vorstellt. Laden Sie die Präsentation, Ihren Code und Ihr finales Modell in der ILU-Gruppe hoch.
# 6.	Bereiten sie sich auf einen Multiple Choice Test (MCT) zu diesem Praktikum vor. Sie müssen bei der Praktikumsabgabe keine Präsentation halten.

# %% [markdown]
# # Import libraries and datasets

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
import os

# %%
with open("/train.p", mode='rb') as training_data_file:
        train = pickle.load(training_data_file)
with open("/valid.p", mode='rb') as validation_data_file:
        valid = pickle.load(validation_data_file)

X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)
X_valid, y_valid = shuffle(X_valid, y_valid)

# %%
# Normalize image to [0, 1]
X_train_norm = X_train / 255
X_valid_norm = X_valid / 255

# %%
# Check that the images have been correctly converted and normalised
i = random.randint(1, len(X_train_norm))
plt.grid(False)
plt.imshow(X_train[i])
plt.figure()
plt.grid(False)
plt.imshow(X_train_norm[i].squeeze(), cmap = 'gray') # cmap

# %% [markdown]
# # Create the Convolutional Neural Network with keras
# For example a CNN that recognises handwritten numbers: [https://adamharley.com/nn_vis/cnn/2d.html](https://adamharley.com/nn_vis/cnn/2d.html)
# Here a fully connected neural network that also recognise handwritten numbers: [https://adamharley.com/nn_vis/mlp/2d.html](https://adamharley.com/nn_vis/mlp/2d.html)

# %% [markdown]
# Use model.add() to add a [Layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers) to your model. Here is a list of layers that might be useful:
# - [Convolution Layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): layers.Conv2D()
# - [Average Pooling](https://www.tensorflow.org/api_docs/python/tf/keras/layers/AveragePooling2D): layers.AveragePooling2D()
# - [Max Pooling](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): layers.MaxPool2D()
# - [Dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout): layers.Dropout()
# - [Flattens](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the input. 2D -> 1D: layers.Flatten()
# - [Densely-connected NN layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense): layers.Dense()

# %%
from tensorflow.keras import datasets, layers, models
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", input_shape=(32, 32, 3)))
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.SpatialDropout2D(0.3))
# kein spacial dropout zwischen layers

# Block 2
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"))

model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.SpatialDropout2D(0.3))

model.add(layers.GlobalAveragePooling2D())


model.add(layers.Dropout(rate=0.4))
# Output Layer
model.add(layers.Dense(units=43, activation="softmax"))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Exception ignored in: <function _xla_gc_callback at 0x79e00dc86020>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# Model: "sequential_30"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_92 (Conv2D)              │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_93 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_59 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_42            │ (None, 16, 16, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_94 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_95 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_60 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_43            │ (None, 8, 8, 64)       │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_16     │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 43)             │         2,795 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 115,371 (450.67 KB)
#  Trainable params: 115,371 (450.67 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Compile your model
# When you want, you can change the [optimizer](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) or the [loss function](https://www.tensorflow.org/api_docs/python/tf/keras/losses).

# %%
model.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # Train your model
# The documentation of the fit method: [https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit)

# %%
# TODO: Choose the batch size and the epochs
history = model.fit(x = X_train_norm,
                    y = y_train,
                    batch_size = 64,
                    epochs = 100,
                    verbose = 1,
                    validation_data = (X_valid_norm, y_valid))
# Out:
# Epoch 1/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - accuracy: 0.0741 - loss: 3.5016 - val_accuracy: 0.1705 - val_loss: 2.9670
# Epoch 2/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1926 - loss: 2.8709 - val_accuracy: 0.2655 - val_loss: 2.3693
# Epoch 3/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3246 - loss: 2.2599 - val_accuracy: 0.4363 - val_loss: 1.8226
# Epoch 4/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4158 - loss: 1.8482 - val_accuracy: 0.5324 - val_loss: 1.5243
# Epoch 5/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4815 - loss: 1.5949 - val_accuracy: 0.6054 - val_loss: 1.3112
# Epoch 6/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5569 - loss: 1.3717 - val_accuracy: 0.7147 - val_loss: 1.0313
# Epoch 7/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6236 - loss: 1.1726 - val_accuracy: 0.7642 - val_loss: 0.8209
# Epoch 8/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6909 - loss: 0.9753 - val_accuracy: 0.8181 - val_loss: 0.6417
# Epoch 9/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7345 - loss: 0.8405 - val_accuracy: 0.8478 - val_loss: 0.5305
# Epoch 10/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7701 - loss: 0.7119 - val_accuracy: 0.8755 - val_loss: 0.4559
# Epoch 11/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8018 - loss: 0.6384 - val_accuracy: 0.8832 - val_loss: 0.4080
# Epoch 12/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8196 - loss: 0.5698 - val_accuracy: 0.9132 - val_loss: 0.3364
# Epoch 13/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8353 - loss: 0.5212 - val_accuracy: 0.9179 - val_loss: 0.3200
# Epoch 14/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8504 - loss: 0.4749 - val_accuracy: 0.9351 - val_loss: 0.2722
# Epoch 15/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8647 - loss: 0.4464 - val_accuracy: 0.9338 - val_loss: 0.2574
# Epoch 16/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8726 - loss: 0.4143 - val_accuracy: 0.9324 - val_loss: 0.2520
# Epoch 17/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8830 - loss: 0.3738 - val_accuracy: 0.9476 - val_loss: 0.1910
# Epoch 18/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8942 - loss: 0.3477 - val_accuracy: 0.9456 - val_loss: 0.1948
# Epoch 19/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8965 - loss: 0.3367 - val_accuracy: 0.9562 - val_loss: 0.1941
# Epoch 20/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9030 - loss: 0.3158 - val_accuracy: 0.9610 - val_loss: 0.1873
# Epoch 21/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9104 - loss: 0.2866 - val_accuracy: 0.9615 - val_loss: 0.1835
# Epoch 22/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9138 - loss: 0.2807 - val_accuracy: 0.9694 - val_loss: 0.1851
# Epoch 23/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9179 - loss: 0.2633 - val_accuracy: 0.9669 - val_loss: 0.1582
# Epoch 24/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9200 - loss: 0.2657 - val_accuracy: 0.9669 - val_loss: 0.1763
# Epoch 25/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9223 - loss: 0.2474 - val_accuracy: 0.9664 - val_loss: 0.1635
# Epoch 26/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9272 - loss: 0.2377 - val_accuracy: 0.9723 - val_loss: 0.1671
# Epoch 27/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9307 - loss: 0.2245 - val_accuracy: 0.9692 - val_loss: 0.1454
# Epoch 28/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9328 - loss: 0.2128 - val_accuracy: 0.9751 - val_loss: 0.1555
# Epoch 29/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9359 - loss: 0.2061 - val_accuracy: 0.9762 - val_loss: 0.1424
# Epoch 30/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9387 - loss: 0.2035 - val_accuracy: 0.9751 - val_loss: 0.1184
# Epoch 31/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9402 - loss: 0.1951 - val_accuracy: 0.9735 - val_loss: 0.1336
# Epoch 32/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9418 - loss: 0.1863 - val_accuracy: 0.9746 - val_loss: 0.1332
# Epoch 33/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9432 - loss: 0.1845 - val_accuracy: 0.9766 - val_loss: 0.1145
# Epoch 34/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9436 - loss: 0.1820 - val_accuracy: 0.9771 - val_loss: 0.1480
# Epoch 35/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9449 - loss: 0.1772 - val_accuracy: 0.9776 - val_loss: 0.1151
# Epoch 36/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9495 - loss: 0.1623 - val_accuracy: 0.9830 - val_loss: 0.0951
# Epoch 37/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9480 - loss: 0.1642 - val_accuracy: 0.9800 - val_loss: 0.0994
# Epoch 38/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9514 - loss: 0.1530 - val_accuracy: 0.9805 - val_loss: 0.1195
# Epoch 39/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9475 - loss: 0.1754 - val_accuracy: 0.9800 - val_loss: 0.1261
# Epoch 40/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9509 - loss: 0.1619 - val_accuracy: 0.9814 - val_loss: 0.1264
# Epoch 41/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9543 - loss: 0.1485 - val_accuracy: 0.9798 - val_loss: 0.1172
# Epoch 42/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9566 - loss: 0.1425 - val_accuracy: 0.9787 - val_loss: 0.1216
# Epoch 43/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9571 - loss: 0.1373 - val_accuracy: 0.9807 - val_loss: 0.1193
# Epoch 44/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9573 - loss: 0.1355 - val_accuracy: 0.9828 - val_loss: 0.1185
# Epoch 45/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9596 - loss: 0.1288 - val_accuracy: 0.9803 - val_loss: 0.0869
# Epoch 46/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9556 - loss: 0.1390 - val_accuracy: 0.9832 - val_loss: 0.1333
# Epoch 47/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9603 - loss: 0.1276 - val_accuracy: 0.9810 - val_loss: 0.1025
# Epoch 48/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9596 - loss: 0.1261 - val_accuracy: 0.9807 - val_loss: 0.1035
# Epoch 49/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9596 - loss: 0.1293 - val_accuracy: 0.9812 - val_loss: 0.1008
# Epoch 50/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9637 - loss: 0.1180 - val_accuracy: 0.9794 - val_loss: 0.0958
# Epoch 51/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9637 - loss: 0.1165 - val_accuracy: 0.9816 - val_loss: 0.1083
# Epoch 52/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9622 - loss: 0.1173 - val_accuracy: 0.9828 - val_loss: 0.1010
# Epoch 53/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9630 - loss: 0.1164 - val_accuracy: 0.9787 - val_loss: 0.0924
# Epoch 54/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9637 - loss: 0.1154 - val_accuracy: 0.9825 - val_loss: 0.0834
# Epoch 55/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9650 - loss: 0.1096 - val_accuracy: 0.9819 - val_loss: 0.0925
# Epoch 56/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9662 - loss: 0.1074 - val_accuracy: 0.9791 - val_loss: 0.1228
# Epoch 57/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9681 - loss: 0.0981 - val_accuracy: 0.9823 - val_loss: 0.0801
# Epoch 58/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9657 - loss: 0.1063 - val_accuracy: 0.9816 - val_loss: 0.0984
# Epoch 59/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9678 - loss: 0.1083 - val_accuracy: 0.9819 - val_loss: 0.1033
# Epoch 60/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9652 - loss: 0.1085 - val_accuracy: 0.9814 - val_loss: 0.0711
# Epoch 61/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9676 - loss: 0.1008 - val_accuracy: 0.9812 - val_loss: 0.1019
# Epoch 62/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9670 - loss: 0.1019 - val_accuracy: 0.9789 - val_loss: 0.0978
# Epoch 63/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9676 - loss: 0.1052 - val_accuracy: 0.9810 - val_loss: 0.0761
# Epoch 64/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9680 - loss: 0.1052 - val_accuracy: 0.9837 - val_loss: 0.0764
# Epoch 65/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9691 - loss: 0.0982 - val_accuracy: 0.9782 - val_loss: 0.1184
# Epoch 66/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9688 - loss: 0.0983 - val_accuracy: 0.9803 - val_loss: 0.0756
# Epoch 67/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9705 - loss: 0.0939 - val_accuracy: 0.9837 - val_loss: 0.1009
# Epoch 68/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9709 - loss: 0.0925 - val_accuracy: 0.9803 - val_loss: 0.1164
# Epoch 69/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9723 - loss: 0.0901 - val_accuracy: 0.9823 - val_loss: 0.0871
# Epoch 70/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9679 - loss: 0.0987 - val_accuracy: 0.9819 - val_loss: 0.0776
# Epoch 71/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9719 - loss: 0.0902 - val_accuracy: 0.9825 - val_loss: 0.0985
# Epoch 72/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9711 - loss: 0.0895 - val_accuracy: 0.9810 - val_loss: 0.1534
# Epoch 73/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9707 - loss: 0.0968 - val_accuracy: 0.9810 - val_loss: 0.1087
# Epoch 74/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9693 - loss: 0.0960 - val_accuracy: 0.9819 - val_loss: 0.0891
# Epoch 75/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9737 - loss: 0.0833 - val_accuracy: 0.9855 - val_loss: 0.1048
# Epoch 76/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9720 - loss: 0.0908 - val_accuracy: 0.9828 - val_loss: 0.0859
# Epoch 77/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9717 - loss: 0.0889 - val_accuracy: 0.9821 - val_loss: 0.1061
# Epoch 78/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9704 - loss: 0.0901 - val_accuracy: 0.9798 - val_loss: 0.1119
# Epoch 79/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9747 - loss: 0.0817 - val_accuracy: 0.9830 - val_loss: 0.0917
# Epoch 80/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9731 - loss: 0.0891 - val_accuracy: 0.9839 - val_loss: 0.0791
# Epoch 81/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9736 - loss: 0.0827 - val_accuracy: 0.9830 - val_loss: 0.0776
# Epoch 82/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9763 - loss: 0.0774 - val_accuracy: 0.9859 - val_loss: 0.0790
# Epoch 83/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9721 - loss: 0.0872 - val_accuracy: 0.9837 - val_loss: 0.0847
# Epoch 84/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9754 - loss: 0.0787 - val_accuracy: 0.9857 - val_loss: 0.0968
# Epoch 85/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9715 - loss: 0.0875 - val_accuracy: 0.9819 - val_loss: 0.0903
# Epoch 86/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9738 - loss: 0.0806 - val_accuracy: 0.9832 - val_loss: 0.0941
# Epoch 87/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9712 - loss: 0.0940 - val_accuracy: 0.9859 - val_loss: 0.1016
# Epoch 88/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9727 - loss: 0.0819 - val_accuracy: 0.9803 - val_loss: 0.0919
# Epoch 89/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9751 - loss: 0.0759 - val_accuracy: 0.9830 - val_loss: 0.0894
# Epoch 90/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9732 - loss: 0.0847 - val_accuracy: 0.9823 - val_loss: 0.0718
# Epoch 91/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9734 - loss: 0.0800 - val_accuracy: 0.9814 - val_loss: 0.1072
# Epoch 92/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9751 - loss: 0.0798 - val_accuracy: 0.9837 - val_loss: 0.0893
# Epoch 93/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9744 - loss: 0.0768 - val_accuracy: 0.9832 - val_loss: 0.0941
# Epoch 94/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9769 - loss: 0.0757 - val_accuracy: 0.9821 - val_loss: 0.0917
# Epoch 95/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9746 - loss: 0.0781 - val_accuracy: 0.9785 - val_loss: 0.1215
# Epoch 96/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9752 - loss: 0.0785 - val_accuracy: 0.9821 - val_loss: 0.1116
# Epoch 97/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9781 - loss: 0.0720 - val_accuracy: 0.9805 - val_loss: 0.1169
# Epoch 98/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9759 - loss: 0.0773 - val_accuracy: 0.9807 - val_loss: 0.1039
# Epoch 99/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9757 - loss: 0.0761 - val_accuracy: 0.9796 - val_loss: 0.1005
# Epoch 100/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9768 - loss: 0.0747 - val_accuracy: 0.9816 - val_loss: 0.0985

# %% [markdown]
# # Visualize Training

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

# %%
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation loss')
plt.title('Training and Validation loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
plt.plot(epochs, accuracy, 'ro', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label = 'Validation accuracy')
plt.title('Training and Validation accuracy')
model.summary()
# Out:
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_88 (Conv2D)              │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_89 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_57 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_40            │ (None, 16, 16, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_90 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_91 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_58 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_41            │ (None, 8, 8, 64)       │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_15     │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 43)             │         2,795 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 346,115 (1.32 MB)
#  Trainable params: 115,371 (450.67 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 230,744 (901.35 KB)

# %% [markdown]
# # Save your model
# Create a folder for your models

# %%
model.save('saved_model/modell_name.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Load your model

# %%
model = tf.keras.models.load_model('saved_model/final_modell.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss, accuracy = model.evaluate(X_valid_norm, y_valid, verbose=0)

print(f'Validierungsgenauigkeit: {accuracy*100:.2f}%')
print(f'Validierungsverlust: {loss:.4f}')
# Out:
# Validierungsgenauigkeit: 98.16%
# Validierungsverlust: 0.0985

# %%
from sklearn.metrics import confusion_matrix

# Normalize image to [0, 1]
X_valid_norm = X_valid / 255

y_pred_probs = model.predict(X_valid_norm)
y_pred = np.argmax(y_pred_probs, axis=1)

cm = confusion_matrix(y_valid, y_pred)

plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
